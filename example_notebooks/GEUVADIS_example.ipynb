# %%
import numpy as np 
import pandas as pd
import SAGEnet.data 
import SAGEnet.tools
from SAGEnet.models import pSAGEnet
from torch.utils.data import DataLoader
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping, LearningRateMonitor
import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
import glob
import os
import pysam

# %% [markdown]
# #### In this notebook, we go through the process of initializing a PersonalGenomeDataset and using this to train a p-SAGE-net model with the GEUVADIS dataset (publicly available).

# %% [markdown]
# #### Before you run this notebook:
# -- follow the steps under "installation" in the main READme to install dependencies and the SAGEnet package.
#
# -- download the pre-processed GEUVADIS expression data 'tpm_pca_annot.csv.gz' from Rastogi et al.: https://github.com/ni-lab/finetuning-enformer/tree/main/process_geuvadis_data/tpm
#
# -- download the GEUVADIS VCF for chromosome 21 (to use as an exapmle) from here: https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-GEUV-1. The file is called 'GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf.gz'
#
# -- run the following lines of code to be able to use pysam with this VCF file:
# ```bash
# gunzip GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf.gz # decompress
# bgzip GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf # recompress using bgzip
# tabix -p vcf GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf.gz # index
# ```
#
# -- download the hg19 genome (to be consisent with GEUVADIS variant calls):
# ```bash
# curl -O https://hgdownload.soe.ucsc.edu/goldenPath/hg19/bigZips/hg19.fa.gz
# gunzip hg19.fa.gz
# ```

# %% [markdown]
# #### Change these paths based on your SAGEnet repo locaiton, where you have saved the files downloaded in the previous step, and where you want to save your model results.

# %%
base_repo_path='/homes/gws/aspiro17/SAGEnet/'

hg19_path='/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/hg19.fa'
expr_path='/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/tpm_pca_annot.csv.gz'
vcf_file_path='/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/GEUVADIS.vcf.gz'

model_save_dir='data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/res/'
os.makedirs(model_save_dir, exist_ok=True)

# %% [markdown]
# #### Use the tss_data_path provided in this github. Since the GEUVADIS variant calls are with respect to hg19 (not hg38, as was the case with our ROSMAP and GTEx data), update the tss and chr columns in gene_meta_info to reflect this.

# %%
tss_data_path=f'{base_repo_path}input_data/gene-ids-and-positions.tsv'
gene_meta_info = pd.read_csv(tss_data_path, sep='\t')
gene_meta_info['chr'] = gene_meta_info['chr_hg19'].str.replace('chr', '', regex=False)
gene_meta_info['tss'] = pd.to_numeric(gene_meta_info['tss_hg19'], errors='coerce').astype('Int64')
gene_meta_info
# Out:
#          gene_name          gene_id    chr_hg38  start_hg38  end_hg38  \
# 0          DDX11L1  ENSG00000223972           1       11869     14409
# 1           WASH7P  ENSG00000227232           1       14404     29570
# 2        MIR6859-1  ENSG00000278267           1       17369     17436
# 3      MIR1302-2HG  ENSG00000243485           1       29554     31109
# 4        MIR1302-2  ENSG00000284332           1       30366     30503
# ...            ...              ...         ...         ...       ...
# 58297   AC240274.1  ENSG00000271254  KI270711.1        4612     29626
# 58298           U1  ENSG00000275405  KI270713.1       21861     22024
# 58299           U1  ENSG00000275987  KI270713.1       30437     30580
# 58300   AC213203.1  ENSG00000277475  KI270713.1       31698     32528
# 58301      FAM231D  ENSG00000268674  KI270713.1       35407     35916
#
#       strand_hg38  tss_hg38 chr_hg19  tss_hg19    tss  chr             ensg  \
# 0               +     11869     chr1   11869.0  11869    1  ENSG00000223972
# 1               -     29570     chr1   29570.0  29570    1  ENSG00000227232
# 2               -     17436     chr1   17436.0  17436    1  ENSG00000278267
# 3               +     29554     chr1   29554.0  29554    1  ENSG00000243485
# 4               +     30366     chr1   30366.0  30366    1  ENSG00000284332
# ...           ...       ...      ...       ...    ...  ...              ...
# 58297           -     29626      NaN       NaN   <NA>  NaN  ENSG00000271254
# 58298           -     22024      NaN       NaN   <NA>  NaN  ENSG00000275405
# 58299           -     30580      NaN       NaN   <NA>  NaN  ENSG00000275987
# 58300           -     32528      NaN       NaN   <NA>  NaN  ENSG00000277475
# 58301           +     35407      NaN       NaN   <NA>  NaN  ENSG00000268674
#
#       strand
# 0          +
# 1          -
# 2          -
# 3          +
# 4          +
# ...      ...
# 58297      -
# 58298      -
# 58299      -
# 58300      -
# 58301      +
#
# [58302 rows x 13 columns]

# %% [markdown]
# #### Load the preprocessed expression data:

# %%
orig_expr_df = pd.read_csv(expr_path)
orig_expr_df
# Out:
#                 TargetID        Gene_Symbol Chr      Coord     HG00096  \
# 0      ENSG00000257527.1  ENSG00000257527.1  16   18505708    0.921724
# 1      ENSG00000151503.7  ENSG00000151503.7  11  134095348   39.400926
# 2      ENSG00000254681.2  ENSG00000254681.2  16   18495797    8.417257
# 3      ENSG00000228477.1  ENSG00000228477.1   1   40428352  267.057590
# 4      ENSG00000159733.9  ENSG00000159733.9   4    2420390    0.227618
# ...                  ...                ...  ..        ...         ...
# 23717  ENSG00000137709.4  ENSG00000137709.4  11  120107349   -0.438372
# 23718  ENSG00000006007.7  ENSG00000006007.7  16   19533467   19.452829
# 23719  ENSG00000172297.6  ENSG00000172297.6   Y   27600708    0.166371
# 23720  ENSG00000125266.5  ENSG00000125266.5  13  107187462    0.139229
# 23721  ENSG00000230711.2  ENSG00000230711.2   6  168690030    0.301975
#
#           HG00097     HG00099     HG00100     HG00101     HG00102  ...  \
# 0        0.848552    0.475993    0.318905    1.814351    0.845431  ...
# 1       35.462012   50.285482   45.931011   37.510652   38.106420  ...
# 2       11.753510   10.750892    9.576572   11.132875   11.370822  ...
# 3      214.369516  287.589232  394.840340  279.594044  201.982560  ...
# 4        0.203908    0.712240    0.433100    0.631554    0.564494  ...
# ...           ...         ...         ...         ...         ...  ...
# 23717    1.930072    0.681640    1.860306    1.169887    1.314488  ...
# 23718   20.194346   16.056744   15.899420   16.054821   21.502305  ...
# 23719    0.139706    0.150852    0.218521    0.039107    0.129921  ...
# 23720    0.213003    0.287849    0.086688    0.251640    0.245102  ...
# 23721    0.302283    0.553291    0.356188    0.257292    0.378519  ...
#
#           NA20828        stable_id  gencode_v12_gene_name  our_gene_name  \
# 0        0.333369  ENSG00000257527         rp11-1212a22.6            NaN
# 1       50.635764  ENSG00000151503                 ncapd3            NaN
# 2        7.895669  ENSG00000254681         rp11-1212a22.3            NaN
# 3      177.177176  ENSG00000228477           rp3-342p20.2            NaN
# 4        0.945074  ENSG00000159733                zfyve28        zfyve28
# ...           ...              ...                    ...            ...
# 23717    0.944036  ENSG00000137709                 pou2f3            NaN
# 23718   20.063232  ENSG00000006007                   gde1            NaN
# 23719    0.111516  ENSG00000172297              golga2p3y            NaN
# 23720    0.079666  ENSG00000125266                  efnb2            NaN
# 23721    0.241215  ENSG00000230711               ctage13p            NaN
#
#        EUR_eGene  YRI_eGene  top_EUR_eqtl_rsid  top_YRI_eqtl_rsid  \
# 0          False      False                NaN                NaN
# 1          False      False                NaN                NaN
# 2          False      False                NaN                NaN
# 3          False      False                NaN                NaN
# 4           True      False          rs4974687                NaN
# ...          ...        ...                ...                ...
# 23717      False      False                NaN                NaN
# 23718      False      False                NaN                NaN
# 23719      False      False                NaN                NaN
# 23720      False      False                NaN                NaN
# 23721      False      False                NaN                NaN
#
#        top_EUR_eqtl_distance  top_YRI_eqtl_distance
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                     9347.0                    NaN
# ...                      ...                    ...
# 23717                    NaN                    NaN
# 23718                    NaN                    NaN
# 23719                    NaN                    NaN
# 23720                    NaN                    NaN
# 23721                    NaN                    NaN
#
# [23722 rows x 475 columns]

# %% [markdown]
# #### Select some example individuals from the GEUVADIS dataset to use as a train, validaiton, and test set (make sure these sample names also exist in the expression data):

# %%
with pysam.VariantFile(vcf_file_path) as vcf:
    all_samps = list(vcf.header.samples)

samps_in_expr_data = [samp for samp in all_samps if samp in orig_expr_df.columns]
print(f'total n samps: {len(samps_in_expr_data)}')

# shuffle and split into train, validation, and test
np.random.seed(12)
shuffled_indices = np.random.permutation(len(samps_in_expr_data))
shuffled_individs = np.array(samps_in_expr_data)[shuffled_indices]  # Convert to numpy array for indexing

# Split data
train_samps = shuffled_individs[:10]
val_samps = shuffled_individs[10:15]
test_samps = shuffled_individs[15:20]
all_samps = np.concatenate((train_samps,val_samps,test_samps))

print(f'train samps: {train_samps}')
print(f'val samps: {val_samps}')
print(f'test samps: {test_samps}')
# Out:
# total n samps: 462
# train samps: ['NA20803' 'NA12830' 'HG00308' 'NA11892' 'NA12249' 'NA20804' 'NA12383'
#  'NA12005' 'NA18498' 'NA19204']
# val samps: ['NA18933' 'NA20536' 'HG00366' 'HG00277' 'NA20514']
# test samps: ['HG00325' 'NA12272' 'HG00100' 'HG00332' 'NA20506']

# %% [markdown]
# #### Select an example gene set to use for model training. Make sure that these genes are on chromosome 21 (this is the example VCF we are using). Usually we would split our gene set into train, validation, and test by chromosome, but since all of these example genes are from chromosome 21, we split randomly.

# %%
chr21_genes = gene_meta_info[gene_meta_info['chr']=='21']['gene_id'].values
chr21_genes_in_expr_data = np.intersect1d(orig_expr_df['stable_id'], chr21_genes)

train_genes=chr21_genes_in_expr_data[:10]
val_genes=chr21_genes_in_expr_data[10:15]
test_genes=chr21_genes_in_expr_data[15:20]

print(train_genes)
# Out:
# ['ENSG00000141956' 'ENSG00000141959' 'ENSG00000142149' 'ENSG00000142156'
#  'ENSG00000142166' 'ENSG00000142168' 'ENSG00000142173' 'ENSG00000142178'
#  'ENSG00000142185' 'ENSG00000142188']

# %% [markdown]
# #### Put the expression data into the format required by PersonalGenomeDataset (indexed by gene IDs, column values are sampele names):

# %%
expr_df = orig_expr_df[all_samps]
expr_df.index=orig_expr_df['stable_id']
expr_df
# Out:
#                     NA20803     NA12830     HG00308     NA11892     NA12249  \
# stable_id
# ENSG00000257527    0.435554    0.328876    0.542901    0.270288    0.906700
# ENSG00000151503   36.769189   32.191375   44.727513   44.521700   22.168308
# ENSG00000254681    7.911369   11.156102    6.884866   10.338751    3.927643
# ENSG00000228477  221.705080  251.016985  267.960374  303.305799  234.466966
# ENSG00000159733    0.445662    1.788335    0.662519    1.522028    1.977999
# ...                     ...         ...         ...         ...         ...
# ENSG00000137709    0.962992    2.417636    2.572387    1.517089    2.405431
# ENSG00000006007   17.547194   19.545290   18.314184   20.772988   18.689712
# ENSG00000172297    0.124084    0.173294    0.203024    0.117988    0.101695
# ENSG00000125266    0.119904    0.015309    0.189959    0.295348    0.184744
# ENSG00000230711    0.295664    0.275888    0.302321    0.333736    0.411049
#
#                     NA20804     NA12383     NA12005     NA18498     NA19204  \
# stable_id
# ENSG00000257527    0.191970    0.380016    0.272329    0.597474    0.205384
# ENSG00000151503   26.766314   44.226758   29.253736   44.163776   31.429208
# ENSG00000254681   10.582101    9.203352   10.578331    8.509440   20.849868
# ENSG00000228477  221.156782  142.271447  328.554436  293.008224  222.329632
# ENSG00000159733    1.391980    1.540233    0.664821    1.555032    0.680732
# ...                     ...         ...         ...         ...         ...
# ENSG00000137709    1.521566    0.596592    2.520589    1.161636    1.646100
# ENSG00000006007   20.295341   18.497651   16.902593   18.332126   17.768566
# ENSG00000172297    0.098348    0.200327    0.120292    0.074053    0.006652
# ENSG00000125266    0.136891    0.215636    0.123038    0.241018    0.058625
# ENSG00000230711    0.333956    0.457673    0.192496    0.360878    0.322105
#
#                     NA18933     NA20536     HG00366     HG00277     NA20514  \
# stable_id
# ENSG00000257527    0.619697    0.871186    0.538308    0.950538    0.301588
# ENSG00000151503   20.655892   47.044519   44.118198   37.670312   43.087610
# ENSG00000254681   17.335315    8.645044    7.983753    8.625198    6.845965
# ENSG00000228477  210.143495  301.558543  272.610373  233.220437  327.936792
# ENSG00000159733    0.167948    0.627373    0.862779    1.957021    1.285814
# ...                     ...         ...         ...         ...         ...
# ENSG00000137709    0.983438    0.377228    1.894994   -0.649883    2.475048
# ENSG00000006007   17.696008   21.477662   30.556087   16.989199   17.506841
# ENSG00000172297    0.112481    0.123586    0.271811    0.300667    0.105189
# ENSG00000125266    0.391730    0.127234    0.171226    0.073759    0.203049
# ENSG00000230711    0.455506    0.232909    0.340308    0.480523    0.570414
#
#                     HG00325     NA12272     HG00100     HG00332     NA20506
# stable_id
# ENSG00000257527    0.411008    0.557917    0.318905    0.678781    0.402872
# ENSG00000151503   48.363630   44.780661   45.931011   37.577450   38.544274
# ENSG00000254681    8.974603   11.913209    9.576572   16.101424    8.348114
# ENSG00000228477  279.922783  168.551674  394.840340  266.975709  263.083702
# ENSG00000159733    0.560031    0.981346    0.433100    0.355617    1.587291
# ...                     ...         ...         ...         ...         ...
# ENSG00000137709    2.395376    1.771172    1.860306    0.496738    0.938476
# ENSG00000006007   16.702770   15.528529   15.899420   21.537412   19.416601
# ENSG00000172297    0.118355    0.135799    0.218521    0.104980    0.117371
# ENSG00000125266    0.366541    0.200787    0.086688    0.216478    0.113176
# ENSG00000230711    0.414058    0.424955    0.356188    0.250241    0.417718
#
# [23722 rows x 20 columns]

# %% [markdown]
# #### Select train and validation gene meta information:

# %%
train_gene_meta = gene_meta_info[gene_meta_info['gene_id'].isin(train_genes)]
val_gene_meta = gene_meta_info[gene_meta_info['gene_id'].isin(val_genes)]
train_gene_meta
# Out:
#       gene_name          gene_id chr_hg38  start_hg38  end_hg38 strand_hg38  \
# 57800      SOD1  ENSG00000142168       21    31659622  31668931           +
# 57807      HUNK  ENSG00000142149       21    31873315  32044633           +
# 57849    IFNAR1  ENSG00000142166       21    33324477  33359862           +
# 57852   TMEM50B  ENSG00000142188       21    33432485  33480011           -
# 58022    PRDM15  ENSG00000141956       21    41798225  41879482           -
# 58066      SIK1  ENSG00000142178       21    43414515  43427128           -
# 58099      PFKL  ENSG00000141959       21    44300051  44327376           +
# 58105     TRPM2  ENSG00000142185       21    44350163  44443081           +
# 58178    COL6A1  ENSG00000142156       21    45981737  46005050           +
# 58184    COL6A2  ENSG00000142173       21    46098097  46132849           +
#
#        tss_hg38 chr_hg19    tss_hg19       tss chr             ensg strand
# 57800  31659622    chr21  33031935.0  33031935  21  ENSG00000142168      +
# 57807  31873315    chr21  33245628.0  33245628  21  ENSG00000142149      +
# 57849  33324477    chr21  34696782.0  34696782  21  ENSG00000142166      +
# 57852  33480011    chr21  34852318.0  34852318  21  ENSG00000142188      -
# 58022  41879482    chr21  43299591.0  43299591  21  ENSG00000141956      -
# 58066  43427128    chr21  44847008.0  44847008  21  ENSG00000142178      -
# 58099  44300051    chr21  45719934.0  45719934  21  ENSG00000141959      +
# 58105  44350163    chr21  45770046.0  45770046  21  ENSG00000142185      +
# 58178  45981737    chr21  47401651.0  47401651  21  ENSG00000142156      +
# 58184  46098097    chr21  47518011.0  47518011  21  ENSG00000142173      +

# %% [markdown]
# #### Initialize training and validation PersonalGenomeDatasets. For more information on how to adjust the parameters to PersonalGenomeDataset to suit your needs, see https://github.com/mostafavilabuw/SAGEnet/blob/main/example_usage.ipynb and the class documentation.

# %%
train_dataset = SAGEnet.data.PersonalGenomeDataset(gene_metadata=train_gene_meta, vcf_file_path=vcf_file_path, hg38_file_path=hg19_path, sample_list=train_samps, expr_data=expr_df,contig_prefix='')
val_subs_dataset = SAGEnet.data.PersonalGenomeDataset(gene_metadata=train_gene_meta, vcf_file_path=vcf_file_path, hg38_file_path=hg19_path, sample_list=train_samps, expr_data=expr_df,contig_prefix='')
val_genes_dataset = SAGEnet.data.PersonalGenomeDataset(gene_metadata=val_gene_meta, vcf_file_path=vcf_file_path, hg38_file_path=hg19_path, sample_list=val_samps, expr_data=expr_df,contig_prefix='')

train_dataloader = DataLoader(train_dataset,shuffle=True,num_workers=1)
val_subs_dataloader = DataLoader(val_subs_dataset, shuffle=False,num_workers=1)
val_genes_dataloader = DataLoader(val_genes_dataset,shuffle=False,num_workers=1)

# %% [markdown]
# #### Initialize a p-SAGE-net model. For more information on how to adjust the parameters to PersonalGenomeDataset to suit your needs, see https://github.com/mostafavilabuw/SAGEnet/blob/main/example_usage.ipynb and the class documentation.

# %%
my_model = pSAGEnet(model_save_dir=model_save_dir)

# %% [markdown]
# #### Set up for model training:

# %%
val_dataloaders=[val_subs_dataloader,val_genes_dataloader]
es = EarlyStopping(monitor="train_gene_val_sub_diff_loss/dataloader_idx_0", patience=5,mode='min')
lr_monitor = LearningRateMonitor(logging_interval='epoch')

# used to save every model epoch 
all_epoch_checkpoint_callback = ModelCheckpoint(
    dirpath=model_save_dir,  
    filename="{epoch}",  
    save_top_k=-1,  
    every_n_epochs=1,
    save_last=False
)

# save last ckpt to be able to resume model training if job is killed 
last_checkpoint_callback = ModelCheckpoint(
    dirpath=model_save_dir,
    filename="last",     
    save_top_k=0,        
    every_n_train_steps=300,  
    save_last=True      
)

ckpt_list = [all_epoch_checkpoint_callback,last_checkpoint_callback]

# %% [markdown]
# #### Set up a trainer:

# %%
wandb_logger = WandbLogger(project='test_project_name', name='test_job_name', id='test_job_name', resume="allow") # change these based on your logging preferences 
device=2 # indicates which GPU
num_nodes=1 # single node training 
max_epochs=1 

trainer = pl.Trainer(
    accelerator="gpu", 
    devices=[int(device)] if device else 1, 
    num_nodes=num_nodes, 
    strategy="ddp" if not device else 'auto', 
    callbacks=ckpt_list, 
    max_epochs=max_epochs, 
    benchmark=False, 
    profiler='simple', 
    gradient_clip_val=1, 
    logger=wandb_logger, 
    log_every_n_steps=10)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# #### Train!

# %%
trainer.fit(my_model, train_dataloader, val_dataloaders=val_dataloaders)
# Out:
# You are using a CUDA device ('NVIDIA RTX A4000') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /homes/gws/aspiro17/.netrc
# wandb: Currently logged in as: spiroannae (spiroannae-university-of-washington) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>./wandb/run-20250506_134609-test_job_name</code>
# Resuming run <strong><a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name/runs/test_job_name' target="_blank">test_job_name</a></strong> to <a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name' target="_blank">https://wandb.ai/spiroannae-university-of-washington/test_project_name</a>
#  View run at <a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name/runs/test_job_name' target="_blank">https://wandb.ai/spiroannae-university-of-washington/test_project_name/runs/test_job_name</a>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name               | Type       | Params | Mode
# ----------------------------------------------------------
# 0 | conv0              | Sequential | 36.9 K | train
# 1 | convlayers         | ModuleList | 2.5 M  | train
# 2 | dilated_convlayers | ModuleList | 0      | train
# 3 | fc0                | Sequential | 65.8 K | train
# 4 | fclayers           | ModuleList | 65.8 K | train
# 5 | diff_fclayers      | ModuleList | 65.8 K | train
# 6 | diff_out           | Sequential | 257    | train
# 7 | ref_out            | Sequential | 257    | train
# ----------------------------------------------------------
# 2.7 M     Trainable params
# 0         Non-trainable params
# 2.7 M     Total params
# 10.811    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /opt/conda/conda-bld/pytorch_1682343967769/work/aten/src/ATen/native/Convolution.cpp:1003.)
#   return F.conv1d(input, weight, bias, self.stride,
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 100/100 [00:35<00:00,  2.83it/s, v_num=name]
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██████████| 100/100 [00:36<00:00,  2.77it/s, v_num=name]
# FIT Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                           	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                            	|  -              	|  6474           	|  109.06         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                               	|  35.374         	|  1              	|  35.374         	|  32.435         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                   	|  0.14454        	|  129            	|  18.646         	|  17.097         	|
# |  [_EvaluationLoop].val_next                                                                                                                                       	|  0.13275        	|  129            	|  17.124         	|  15.702         	|
# |  run_training_batch                                                                                                                                               	|  0.10886        	|  100            	|  10.886         	|  9.9813         	|
# |  [LightningModule]pSAGEnet.optimizer_step                                                                                                                         	|  0.10869        	|  100            	|  10.869         	|  9.9661         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                       	|  0.063604       	|  100            	|  6.3604         	|  5.8319         	|
# |  [LightningModule]pSAGEnet.configure_gradient_clipping                                                                                                            	|  0.062001       	|  100            	|  6.2001         	|  5.685          	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                          	|  0.029799       	|  100            	|  2.9799         	|  2.7323         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                     	|  0.01438        	|  100            	|  1.438          	|  1.3185         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end         	|  0.36048        	|  1              	|  0.36048        	|  0.33053        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_epoch_end       	|  0.34043        	|  1              	|  0.34043        	|  0.31214        	|
# |  [LightningModule]pSAGEnet.on_validation_epoch_end                                                                                                                	|  0.1582         	|  2              	|  0.31641        	|  0.29012        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                	|  0.0019155      	|  129            	|  0.24709        	|  0.22656        	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                     	|  0.0015555      	|  100            	|  0.15555        	|  0.14262        	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                   	|  0.0005394      	|  229            	|  0.12352        	|  0.11326        	|
# |  [LightningModule]pSAGEnet.transfer_batch_to_device                                                                                                               	|  0.0005064      	|  229            	|  0.11597        	|  0.10633        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                              	|  0.00011778     	|  129            	|  0.015193       	|  0.013931       	|
# |  [LightningModule]pSAGEnet.optimizer_zero_grad                                                                                                                    	|  9.0179e-05     	|  100            	|  0.0090179      	|  0.0082687      	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                         	|  0.0087814      	|  1              	|  0.0087814      	|  0.0080518      	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                      	|  0.0021679      	|  2              	|  0.0043357      	|  0.0039755      	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                    	|  0.0016835      	|  2              	|  0.0033669      	|  0.0030872      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                              	|  0.0022542      	|  1              	|  0.0022542      	|  0.0020669      	|
# |  [LightningModule]pSAGEnet.lr_scheduler_step                                                                                                                      	|  2.1319e-05     	|  100            	|  0.0021319      	|  0.0019548      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                   	|  0.0017696      	|  1              	|  0.0017696      	|  0.0016225      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end         	|  1.7533e-05     	|  100            	|  0.0017533      	|  0.0016076      	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                  	|  0.0015501      	|  1              	|  0.0015501      	|  0.0014213      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                      	|  0.0014993      	|  1              	|  0.0014993      	|  0.0013748      	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                           	|  0.0010461      	|  1              	|  0.0010461      	|  0.00095921     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_batch_end       	|  8.0426e-06     	|  100            	|  0.00080426     	|  0.00073744     	|
# |  [LightningModule]pSAGEnet.on_validation_model_eval                                                                                                               	|  0.00033274     	|  2              	|  0.00066548     	|  0.00061019     	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                     	|  0.0006286      	|  1              	|  0.0006286      	|  0.00057637     	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                   	|  3.1836e-06     	|  129            	|  0.00041069     	|  0.00037657     	|
# |  [LightningModule]pSAGEnet.on_before_batch_transfer                                                                                                               	|  1.6315e-06     	|  229            	|  0.00037361     	|  0.00034257     	|
# |  [LightningModule]pSAGEnet.configure_optimizers                                                                                                                   	|  0.00029908     	|  1              	|  0.00029908     	|  0.00027423     	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                        	|  2.8486e-06     	|  100            	|  0.00028486     	|  0.00026119     	|
# |  [LightningModule]pSAGEnet.on_after_batch_transfer                                                                                                                	|  1.1013e-06     	|  229            	|  0.0002522      	|  0.00023125     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                    	|  2.3435e-06     	|  100            	|  0.00023435     	|  0.00021488     	|
# |  [LightningModule]pSAGEnet.on_validation_model_zero_grad                                                                                                          	|  0.00022968     	|  1              	|  0.00022968     	|  0.0002106      	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                      	|  2.2856e-06     	|  100            	|  0.00022856     	|  0.00020957     	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                   	|  2.1156e-06     	|  100            	|  0.00021156     	|  0.00019398     	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                 	|  1.5715e-06     	|  129            	|  0.00020273     	|  0.00018588     	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                     	|  1.8477e-06     	|  100            	|  0.00018477     	|  0.00016942     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                               	|  1.687e-06      	|  100            	|  0.0001687      	|  0.00015469     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end    	|  1.2375e-06     	|  129            	|  0.00015964     	|  0.00014637     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start  	|  1.1781e-06     	|  129            	|  0.00015198     	|  0.00013935     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_batch_end  	|  1.122e-06      	|  129            	|  0.00014474     	|  0.00013271     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end          	|  6.8935e-05     	|  2              	|  0.00013787     	|  0.00012641     	|
# |  [LightningModule]pSAGEnet.on_validation_batch_start                                                                                                              	|  1.0083e-06     	|  129            	|  0.00013007     	|  0.00011926     	|
# |  [LightningModule]pSAGEnet.on_validation_batch_end                                                                                                                	|  1.0042e-06     	|  129            	|  0.00012954     	|  0.00011878     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_batch_start	|  9.8807e-07     	|  129            	|  0.00012746     	|  0.00011687     	|
# |  [LightningModule]pSAGEnet.on_train_batch_end                                                                                                                     	|  1.1872e-06     	|  100            	|  0.00011872     	|  0.00010886     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward          	|  1.1858e-06     	|  100            	|  0.00011858     	|  0.00010873     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                       	|  1.1806e-06     	|  100            	|  0.00011806     	|  0.00010825     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad        	|  1.1129e-06     	|  100            	|  0.00011129     	|  0.00010205     	|
# |  [LightningModule]pSAGEnet.on_after_backward                                                                                                                      	|  1.1111e-06     	|  100            	|  0.00011111     	|  0.00010188     	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                      	|  1.1032e-06     	|  100            	|  0.00011032     	|  0.00010116     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward         	|  1.0971e-06     	|  100            	|  0.00010971     	|  0.0001006      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start       	|  1.0927e-06     	|  100            	|  0.00010927     	|  0.00010019     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_before_backward       	|  1.0801e-06     	|  100            	|  0.00010801     	|  9.9033e-05     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                         	|  1.0609e-06     	|  100            	|  0.00010609     	|  9.7274e-05     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                        	|  1.0421e-06     	|  100            	|  0.00010421     	|  9.555e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_before_zero_grad      	|  1.0323e-06     	|  100            	|  0.00010323     	|  9.4657e-05     	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                  	|  1.0284e-06     	|  100            	|  0.00010284     	|  9.4297e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_after_backward        	|  1.0191e-06     	|  100            	|  0.00010191     	|  9.3443e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step   	|  1.0002e-06     	|  100            	|  0.00010002     	|  9.1712e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_batch_start     	|  9.9083e-07     	|  100            	|  9.9083e-05     	|  9.0851e-05     	|
# |  [LightningModule]pSAGEnet.on_before_zero_grad                                                                                                                    	|  9.8049e-07     	|  100            	|  9.8049e-05     	|  8.9902e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                              	|  9.7843e-07     	|  100            	|  9.7843e-05     	|  8.9714e-05     	|
# |  [LightningModule]pSAGEnet.on_train_batch_start                                                                                                                   	|  9.6534e-07     	|  100            	|  9.6534e-05     	|  8.8514e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_before_optimizer_step 	|  9.6276e-07     	|  100            	|  9.6276e-05     	|  8.8277e-05     	|
# |  [LightningModule]pSAGEnet.on_before_backward                                                                                                                     	|  8.7273e-07     	|  100            	|  8.7273e-05     	|  8.0022e-05     	|
# |  [LightningModule]pSAGEnet.on_before_optimizer_step                                                                                                               	|  8.3194e-07     	|  100            	|  8.3194e-05     	|  7.6282e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.setup                    	|  3.4315e-05     	|  1              	|  3.4315e-05     	|  3.1464e-05     	|
# |  [LightningModule]pSAGEnet.on_validation_end                                                                                                                      	|  1.4848e-05     	|  2              	|  2.9697e-05     	|  2.723e-05      	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                         	|  1.4012e-05     	|  2              	|  2.8023e-05     	|  2.5695e-05     	|
# |  [LightningModule]pSAGEnet.on_train_start                                                                                                                         	|  2.0729e-05     	|  1              	|  2.0729e-05     	|  1.9007e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                      	|  1.8094e-05     	|  1              	|  1.8094e-05     	|  1.6591e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_end        	|  8.887e-06      	|  2              	|  1.7774e-05     	|  1.6297e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                    	|  1.4547e-05     	|  1              	|  1.4547e-05     	|  1.3338e-05     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                            	|  1.3546e-05     	|  1              	|  1.3546e-05     	|  1.2421e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                	|  6.1065e-06     	|  2              	|  1.2213e-05     	|  1.1198e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                    	|  1.1081e-05     	|  1              	|  1.1081e-05     	|  1.016e-05      	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                       	|  1.077e-05      	|  1              	|  1.077e-05      	|  9.8752e-06     	|
# |  [LightningModule]pSAGEnet.on_train_epoch_start                                                                                                                   	|  1.06e-05       	|  1              	|  1.06e-05       	|  9.7193e-06     	|
# |  [LightningModule]pSAGEnet.on_validation_start                                                                                                                    	|  4.994e-06      	|  2              	|  9.988e-06      	|  9.1582e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                              	|  9.849e-06      	|  1              	|  9.849e-06      	|  9.0307e-06     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                       	|  4.6485e-06     	|  2              	|  9.2969e-06     	|  8.5245e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_epoch_start	|  4.0575e-06     	|  2              	|  8.115e-06      	|  7.4408e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                              	|  4.0125e-06     	|  2              	|  8.025e-06      	|  7.3582e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                               	|  3.512e-06      	|  2              	|  7.024e-06      	|  6.4404e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                  	|  6.212e-06      	|  1              	|  6.212e-06      	|  5.6959e-06     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                     	|  2.86e-06       	|  2              	|  5.72e-06       	|  5.2447e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                             	|  4.789e-06      	|  1              	|  4.789e-06      	|  4.3911e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                           	|  4.689e-06      	|  1              	|  4.689e-06      	|  4.2994e-06     	|
# |  [LightningModule]pSAGEnet.configure_callbacks                                                                                                                    	|  4.549e-06      	|  1              	|  4.549e-06      	|  4.171e-06      	|
# |  [LightningModule]pSAGEnet.on_fit_start                                                                                                                           	|  3.847e-06      	|  1              	|  3.847e-06      	|  3.5274e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start             	|  3.487e-06      	|  1              	|  3.487e-06      	|  3.1973e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                        	|  3.186e-06      	|  1              	|  3.186e-06      	|  2.9213e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end    	|  1.3125e-06     	|  2              	|  2.625e-06      	|  2.4069e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                     	|  2.585e-06      	|  1              	|  2.585e-06      	|  2.3702e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                 	|  1.288e-06      	|  2              	|  2.576e-06      	|  2.362e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start               	|  2.544e-06      	|  1              	|  2.544e-06      	|  2.3326e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start        	|  1.2425e-06     	|  2              	|  2.485e-06      	|  2.2785e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                        	|  1.222e-06      	|  2              	|  2.444e-06      	|  2.2409e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                   	|  1.202e-06      	|  2              	|  2.404e-06      	|  2.2043e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                 	|  1.1375e-06     	|  2              	|  2.275e-06      	|  2.086e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_start      	|  1.112e-06      	|  2              	|  2.224e-06      	|  2.0392e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_epoch_end  	|  1.097e-06      	|  2              	|  2.194e-06      	|  2.0117e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint         	|  1.082e-06      	|  2              	|  2.164e-06      	|  1.9842e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                               	|  2.064e-06      	|  1              	|  2.064e-06      	|  1.8925e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_save_checkpoint       	|  1.017e-06      	|  2              	|  2.034e-06      	|  1.865e-06      	|
# |  [Callback]ModelSummary.setup                                                                                                                                     	|  2.033e-06      	|  1              	|  2.033e-06      	|  1.8641e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start       	|  2.004e-06      	|  1              	|  2.004e-06      	|  1.8375e-06     	|
# |  [LightningModule]pSAGEnet.on_save_checkpoint                                                                                                                     	|  9.9701e-07     	|  2              	|  1.994e-06      	|  1.8283e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start  	|  9.9197e-07     	|  2              	|  1.9839e-06     	|  1.8191e-06     	|
# |  [LightningModule]pSAGEnet.setup                                                                                                                                  	|  1.963e-06      	|  1              	|  1.963e-06      	|  1.7999e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_start           	|  1.7131e-06     	|  1              	|  1.7131e-06     	|  1.5707e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                      	|  1.634e-06      	|  1              	|  1.634e-06      	|  1.4982e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end        	|  1.563e-06      	|  1              	|  1.563e-06      	|  1.4331e-06     	|
# |  [LightningModule]pSAGEnet.on_train_epoch_end                                                                                                                     	|  1.453e-06      	|  1              	|  1.453e-06      	|  1.3323e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end               	|  1.442e-06      	|  1              	|  1.442e-06      	|  1.3222e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_fit_start             	|  1.402e-06      	|  1              	|  1.402e-06      	|  1.2856e-06     	|
# |  [LightningModule]pSAGEnet.on_validation_epoch_start                                                                                                              	|  6.7649e-07     	|  2              	|  1.353e-06      	|  1.2406e-06     	|
# |  [LightningModule]pSAGEnet.on_train_end                                                                                                                           	|  1.302e-06      	|  1              	|  1.302e-06      	|  1.1939e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start      	|  1.273e-06      	|  1              	|  1.273e-06      	|  1.1672e-06     	|
# |  [LightningModule]pSAGEnet.teardown                                                                                                                               	|  1.273e-06      	|  1              	|  1.273e-06      	|  1.1672e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                	|  1.263e-06      	|  1              	|  1.263e-06      	|  1.1581e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_epoch_start     	|  1.222e-06      	|  1              	|  1.222e-06      	|  1.1205e-06     	|
# |  [LightningModule]pSAGEnet.on_fit_end                                                                                                                             	|  1.203e-06      	|  1              	|  1.203e-06      	|  1.1031e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_sanity_check_start    	|  1.192e-06      	|  1              	|  1.192e-06      	|  1.0929e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                  	|  1.112e-06      	|  1              	|  1.112e-06      	|  1.0196e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_sanity_check_end      	|  1.102e-06      	|  1              	|  1.102e-06      	|  1.0105e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end                 	|  1.012e-06      	|  1              	|  1.012e-06      	|  9.2792e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                   	|  1.002e-06      	|  1              	|  1.002e-06      	|  9.1874e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.teardown                 	|  9.9197e-07     	|  1              	|  9.9197e-07     	|  9.0956e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_end             	|  9.62e-07       	|  1              	|  9.62e-07       	|  8.8207e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_fit_end               	|  8.8202e-07     	|  1              	|  8.8202e-07     	|  8.0874e-07     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
