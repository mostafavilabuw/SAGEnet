# %%
import numpy as np 
import pandas as pd
import SAGEnet.data 
import SAGEnet.tools
from SAGEnet.models import pSAGEnet
from torch.utils.data import DataLoader
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping, LearningRateMonitor
import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
import glob
import os
import pysam
# Out:
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# #### In this notebook, we go through the process of initializing a PersonalGenomeDataset and using this to train a p-SAGE-net model with the GEUVADIS dataset (publicly available).

# %% [markdown]
# #### Before you run this notebook:
# -- follow the steps under "installation" in the main READme to install dependencies and the SAGEnet package.
#
# -- download the pre-processed GEUVADIS expression data 'tpm_pca_annot.csv.gz' from Rastogi et al.: https://github.com/ni-lab/finetuning-enformer/tree/main/process_geuvadis_data/tpm
#
# -- download the GEUVADIS VCF for chromosome 21 (to use as an example) from here: https://www.ebi.ac.uk/biostudies/arrayexpress/studies/E-GEUV-1. The file is called 'GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf.gz'
#
# -- run the following lines of code to be able to use pysam with this VCF file:
# ```bash
# gunzip GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf.gz # decompress
# bgzip GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf # recompress using bgzip
# tabix -p vcf GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.vcf.gz # index
# ```
#
# -- download the hg19 genome (to be consisent with GEUVADIS variant calls):
# ```bash
# curl -O https://hgdownload.soe.ucsc.edu/goldenPath/hg19/bigZips/hg19.fa.gz
# gunzip hg19.fa.gz
# ```

# %% [markdown]
# #### Change these paths based on your SAGEnet repo locaiton, where you have saved the files downloaded in the previous step, and where you want to save your model results.

# %%
base_repo_path='/homes/gws/aspiro17/SAGEnet/'

hg19_path='/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/hg19.fa'
expr_path='/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/corrected_log_tpm.annot.csv.gz'
vcf_file_path='/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/all_vcf_files/GEUVADIS.chr21.PH1PH2_465.IMPFRQFILT_BIALLELIC_PH.annotv2.genotypes.bgz'

model_save_dir='data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/res/'
os.makedirs(model_save_dir, exist_ok=True)

# %% [markdown]
# #### Use the tss_data_path provided in this github. Since the GEUVADIS variant calls are with respect to hg19 (not hg38, as was the case with our ROSMAP and GTEx data), update the tss and chr columns in gene_meta_info to reflect this.

# %%
tss_data_path=f'{base_repo_path}input_data/gene-ids-and-positions.tsv'
gene_meta_info = pd.read_csv(tss_data_path, sep="\t",index_col='region_id')
gene_meta_info['chr'] = gene_meta_info['chr_hg19'].str.replace('chr', '', regex=False)
gene_meta_info['tss'] = pd.to_numeric(gene_meta_info['tss_hg19'], errors='coerce').astype('Int64')
gene_meta_info
# Out:
#                    gene_name          gene_id    chr_hg38  start_hg38  \
# region_id
# ENSG00000223972      DDX11L1  ENSG00000223972           1       11869
# ENSG00000227232       WASH7P  ENSG00000227232           1       14404
# ENSG00000278267    MIR6859-1  ENSG00000278267           1       17369
# ENSG00000243485  MIR1302-2HG  ENSG00000243485           1       29554
# ENSG00000284332    MIR1302-2  ENSG00000284332           1       30366
# ...                      ...              ...         ...         ...
# ENSG00000271254   AC240274.1  ENSG00000271254  KI270711.1        4612
# ENSG00000275405           U1  ENSG00000275405  KI270713.1       21861
# ENSG00000275987           U1  ENSG00000275987  KI270713.1       30437
# ENSG00000277475   AC213203.1  ENSG00000277475  KI270713.1       31698
# ENSG00000268674      FAM231D  ENSG00000268674  KI270713.1       35407
#
#                  end_hg38 strand_hg38  tss_hg38 chr_hg19  tss_hg19    tss  \
# region_id
# ENSG00000223972     14409           +     11869     chr1   11869.0  11869
# ENSG00000227232     29570           -     29570     chr1   29570.0  29570
# ENSG00000278267     17436           -     17436     chr1   17436.0  17436
# ENSG00000243485     31109           +     29554     chr1   29554.0  29554
# ENSG00000284332     30503           +     30366     chr1   30366.0  30366
# ...                   ...         ...       ...      ...       ...    ...
# ENSG00000271254     29626           -     29626      NaN       NaN   <NA>
# ENSG00000275405     22024           -     22024      NaN       NaN   <NA>
# ENSG00000275987     30580           -     30580      NaN       NaN   <NA>
# ENSG00000277475     32528           -     32528      NaN       NaN   <NA>
# ENSG00000268674     35916           +     35407      NaN       NaN   <NA>
#
#                  chr             ensg strand    pos
# region_id
# ENSG00000223972    1  ENSG00000223972      +  11869
# ENSG00000227232    1  ENSG00000227232      -  29570
# ENSG00000278267    1  ENSG00000278267      -  17436
# ENSG00000243485    1  ENSG00000243485      +  29554
# ENSG00000284332    1  ENSG00000284332      +  30366
# ...              ...              ...    ...    ...
# ENSG00000271254  NaN  ENSG00000271254      -  29626
# ENSG00000275405  NaN  ENSG00000275405      -  22024
# ENSG00000275987  NaN  ENSG00000275987      -  30580
# ENSG00000277475  NaN  ENSG00000277475      -  32528
# ENSG00000268674  NaN  ENSG00000268674      +  35407
#
# [58302 rows x 14 columns]

# %% [markdown]
# #### Load the preprocessed expression data:

# %%
orig_expr_df = pd.read_csv(expr_path)
orig_expr_df
# Out:
#                 TargetID        Gene_Symbol Chr      Coord   HG00096  \
# 0      ENSG00000257527.1  ENSG00000257527.1  16   18505708 -0.057361
# 1      ENSG00000151503.7  ENSG00000151503.7  11  134095348  3.653703
# 2      ENSG00000254681.2  ENSG00000254681.2  16   18495797  2.088882
# 3      ENSG00000228477.1  ENSG00000228477.1   1   40428352  5.579332
# 4      ENSG00000159733.9  ENSG00000159733.9   4    2420390 -0.984586
# ...                  ...                ...  ..        ...       ...
# 23717  ENSG00000137709.4  ENSG00000137709.4  11  120107349 -1.573193
# 23718  ENSG00000006007.7  ENSG00000006007.7  16   19533467  2.938774
# 23719  ENSG00000172297.6  ENSG00000172297.6   Y   27600708 -1.760798
# 23720  ENSG00000125266.5  ENSG00000125266.5  13  107187462 -1.917913
# 23721  ENSG00000230711.2  ENSG00000230711.2   6  168690030 -1.243145
#
#         HG00097   HG00099   HG00100   HG00101   HG00102  ...   NA20828  \
# 0     -0.313160 -0.684395 -1.209085 -0.012644 -0.270612  ... -1.127696
# 1      3.555238  3.969966  3.832266  3.620463  3.682108  ...  3.984807
# 2      2.326419  2.128807  2.199625  2.331783  2.627187  ...  1.565265
# 3      5.352685  5.758683  6.045576  5.563191  5.176924  ...  5.187391
# 4     -1.124469 -0.433654 -1.025796 -0.705150 -1.333362  ...  0.044033
# ...         ...       ...       ...       ...       ...  ...       ...
# 23717  0.184419 -1.035174  0.130528 -0.713233  0.147750  ... -0.414130
# 23718  2.976678  2.681771  2.732348  2.782939  3.024868  ...  3.017779
# 23719 -1.955373 -1.859498 -1.676782 -4.246593 -2.011718  ... -2.351444
# 23720 -1.706478 -1.403048 -2.520733 -1.504605 -1.454579  ... -2.262784
# 23721 -1.266781 -0.492633 -1.060061 -1.336529 -1.087393  ... -1.386520
#
#              stable_id  gencode_v12_gene_name  our_gene_name  EUR_eGene  \
# 0      ENSG00000257527         rp11-1212a22.6            NaN      False
# 1      ENSG00000151503                 ncapd3            NaN      False
# 2      ENSG00000254681         rp11-1212a22.3            NaN      False
# 3      ENSG00000228477           rp3-342p20.2            NaN      False
# 4      ENSG00000159733                zfyve28        zfyve28       True
# ...                ...                    ...            ...        ...
# 23717  ENSG00000137709                 pou2f3            NaN      False
# 23718  ENSG00000006007                   gde1            NaN      False
# 23719  ENSG00000172297              golga2p3y            NaN      False
# 23720  ENSG00000125266                  efnb2            NaN      False
# 23721  ENSG00000230711               ctage13p            NaN      False
#
#        YRI_eGene  top_EUR_eqtl_rsid  top_YRI_eqtl_rsid  top_EUR_eqtl_distance  \
# 0          False                NaN                NaN                    NaN
# 1          False                NaN                NaN                    NaN
# 2          False                NaN                NaN                    NaN
# 3          False                NaN                NaN                    NaN
# 4          False          rs4974687                NaN                 9347.0
# ...          ...                ...                ...                    ...
# 23717      False                NaN                NaN                    NaN
# 23718      False                NaN                NaN                    NaN
# 23719      False                NaN                NaN                    NaN
# 23720      False                NaN                NaN                    NaN
# 23721      False                NaN                NaN                    NaN
#
#        top_YRI_eqtl_distance
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 23717                    NaN
# 23718                    NaN
# 23719                    NaN
# 23720                    NaN
# 23721                    NaN
#
# [23722 rows x 475 columns]

# %% [markdown]
# #### Select some example individuals from the GEUVADIS dataset to use as a train, validaiton, and test set (make sure these sample names also exist in the expression data):

# %%
with pysam.VariantFile(vcf_file_path) as vcf:
    all_samps = list(vcf.header.samples)

samps_in_expr_data = [samp for samp in all_samps if samp in orig_expr_df.columns]
print(f'total n samps: {len(samps_in_expr_data)}')

# shuffle and split into train, validation, and test
np.random.seed(12)
shuffled_indices = np.random.permutation(len(samps_in_expr_data))
shuffled_individs = np.array(samps_in_expr_data)[shuffled_indices]  # Convert to numpy array for indexing

# Split data
train_samps = shuffled_individs[:10]
val_samps = shuffled_individs[10:15]
test_samps = shuffled_individs[15:20]
all_samps = np.concatenate((train_samps,val_samps,test_samps))

print(f'train samps: {train_samps}')
print(f'val samps: {val_samps}')
print(f'test samps: {test_samps}')
# Out:
# total n samps: 462
# train samps: ['NA20803' 'NA12830' 'HG00308' 'NA11892' 'NA12249' 'NA20804' 'NA12383'
#  'NA12005' 'NA18498' 'NA19204']
# val samps: ['NA18933' 'NA20536' 'HG00366' 'HG00277' 'NA20514']
# test samps: ['HG00325' 'NA12272' 'HG00100' 'HG00332' 'NA20506']
# [W::bcf_hdr_check_sanity] GL should be declared as Number=G

# %% [markdown]
# #### Select an example gene set to use for model training. Make sure that these genes are on chromosome 21 (this is the example VCF we are using). Usually we would split our gene set into train, validation, and test by chromosome, but since all of these example genes are from chromosome 21, we split randomly.

# %%
chr21_genes = gene_meta_info[gene_meta_info['chr']=='21'].index.values
chr21_genes_in_expr_data = np.intersect1d(orig_expr_df['stable_id'], chr21_genes)

train_genes=chr21_genes_in_expr_data[:10]
val_genes=chr21_genes_in_expr_data[10:15]
test_genes=chr21_genes_in_expr_data[15:20]

print(train_genes)
# Out:
# ['ENSG00000141956' 'ENSG00000141959' 'ENSG00000142149' 'ENSG00000142156'
#  'ENSG00000142166' 'ENSG00000142168' 'ENSG00000142173' 'ENSG00000142178'
#  'ENSG00000142185' 'ENSG00000142188']

# %% [markdown]
# #### Put the expression data into the format required by PersonalGenomeDataset (indexed by gene IDs, column values are sampele names):

# %%
expr_df = orig_expr_df[all_samps]
expr_df.index=orig_expr_df['stable_id']
expr_df
# Out:
#                   NA20803   NA12830   HG00308   NA11892   NA12249   NA20804  \
# stable_id
# ENSG00000257527 -0.955159 -1.045982 -0.898474 -1.269318 -0.439611 -1.501674
# ENSG00000151503  3.577920  3.348796  3.731877  3.543473  2.912565  3.160353
# ENSG00000254681  2.036221  2.381775  1.782837  2.297884  1.203374  2.326845
# ENSG00000228477  5.368516  5.535018  5.634284  5.643026  5.420429  5.404369
# ENSG00000159733 -1.109934  0.777448 -1.476499  0.361167  1.048617  0.379605
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000137709 -0.753234  1.269964  1.190510  0.744741  1.454462 -0.052893
# ENSG00000006007  2.873027  2.954443  2.898562  3.062070  2.956746  2.952475
# ENSG00000172297 -2.161487 -1.467204 -1.569799 -3.318952 -3.600092 -2.635539
# ENSG00000125266 -2.262790 -4.316878 -1.681150 -0.973592 -1.541674 -2.422960
# ENSG00000230711 -1.333447 -1.550798 -1.179340 -1.182277 -0.912159 -1.103018
#
#                   NA12383   NA12005   NA18498   NA19204   NA18933   NA20536  \
# stable_id
# ENSG00000257527 -0.995744 -1.149879 -0.563737 -4.145182 -0.436156 -0.204412
# ENSG00000151503  3.774759  3.223603  3.737564  3.546188  3.161365  3.816250
# ENSG00000254681  2.016927  2.308166  2.080930  2.606330  2.723239  2.120876
# ENSG00000228477  5.088399  5.791136  5.688514  5.398632  5.359600  5.697734
# ENSG00000159733  0.330535 -0.719827  0.589121 -0.351958 -1.245378 -0.539014
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000137709 -0.243307  0.646964 -0.528754  0.574150 -0.544949 -0.964710
# ENSG00000006007  2.862663  2.795224  2.872930  2.854083  2.841855  3.065036
# ENSG00000172297 -1.343513 -2.140923 -2.417205 -4.356008 -2.056515 -1.888358
# ENSG00000125266 -1.382643 -2.681801 -1.539816 -2.595265 -1.127857 -2.148006
# ENSG00000230711 -0.702387 -1.547151 -1.041799 -1.100820 -0.772437 -1.402377
#
#                   HG00366   HG00277   NA20514   HG00325   NA12272   HG00100  \
# stable_id
# ENSG00000257527 -0.663628  0.136591 -0.832092 -0.838569 -0.493279 -1.209085
# ENSG00000151503  3.732621  3.606528  3.703678  3.824468  3.823922  3.832266
# ENSG00000254681  1.989878  2.151429  1.922922  2.122954  2.603052  2.199625
# ENSG00000228477  5.582426  5.460593  5.795808  5.631186  5.169079  6.045576
# ENSG00000159733 -0.348463  0.695440  0.097511 -0.615162  0.057834 -1.025796
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000137709  0.262337 -1.183316  0.643111  0.722426  0.865159  0.130528
# ENSG00000006007  3.412581  2.847144  2.869451  2.781907  2.691973  2.732348
# ENSG00000172297 -1.292487 -1.651868 -2.030265 -2.172085 -1.980753 -1.676782
# ENSG00000125266 -2.290481 -2.639456 -1.717789 -0.977396 -1.692599 -2.520733
# ENSG00000230711 -1.087596 -0.799281 -0.613617 -0.950910 -0.857901 -1.060061
#
#                   HG00332   NA20506
# stable_id
# ENSG00000257527 -0.170537 -0.912007
# ENSG00000151503  3.642056  3.665946
# ENSG00000254681  2.489873  2.179513
# ENSG00000228477  5.560037  5.496706
# ENSG00000159733 -0.905647  0.471690
# ...                   ...       ...
# ENSG00000137709 -0.190743 -0.380437
# ENSG00000006007  3.031229  3.016198
# ENSG00000172297 -2.083555 -2.157134
# ENSG00000125266 -1.749358 -2.967128
# ENSG00000230711 -1.248122 -0.871308
#
# [23722 rows x 20 columns]

# %% [markdown]
# #### Select train and validation gene meta information:

# %%
train_gene_meta = gene_meta_info.loc[train_genes]
val_gene_meta = gene_meta_info.loc[val_genes]
train_gene_meta
# Out:
#                 gene_name          gene_id chr_hg38  start_hg38  end_hg38  \
# region_id
# ENSG00000141956    PRDM15  ENSG00000141956       21    41798225  41879482
# ENSG00000141959      PFKL  ENSG00000141959       21    44300051  44327376
# ENSG00000142149      HUNK  ENSG00000142149       21    31873315  32044633
# ENSG00000142156    COL6A1  ENSG00000142156       21    45981737  46005050
# ENSG00000142166    IFNAR1  ENSG00000142166       21    33324477  33359862
# ENSG00000142168      SOD1  ENSG00000142168       21    31659622  31668931
# ENSG00000142173    COL6A2  ENSG00000142173       21    46098097  46132849
# ENSG00000142178      SIK1  ENSG00000142178       21    43414515  43427128
# ENSG00000142185     TRPM2  ENSG00000142185       21    44350163  44443081
# ENSG00000142188   TMEM50B  ENSG00000142188       21    33432485  33480011
#
#                 strand_hg38  tss_hg38 chr_hg19    tss_hg19       tss chr  \
# region_id
# ENSG00000141956           -  41879482    chr21  43299591.0  43299591  21
# ENSG00000141959           +  44300051    chr21  45719934.0  45719934  21
# ENSG00000142149           +  31873315    chr21  33245628.0  33245628  21
# ENSG00000142156           +  45981737    chr21  47401651.0  47401651  21
# ENSG00000142166           +  33324477    chr21  34696782.0  34696782  21
# ENSG00000142168           +  31659622    chr21  33031935.0  33031935  21
# ENSG00000142173           +  46098097    chr21  47518011.0  47518011  21
# ENSG00000142178           -  43427128    chr21  44847008.0  44847008  21
# ENSG00000142185           +  44350163    chr21  45770046.0  45770046  21
# ENSG00000142188           -  33480011    chr21  34852318.0  34852318  21
#
#                             ensg strand       pos
# region_id
# ENSG00000141956  ENSG00000141956      -  41879482
# ENSG00000141959  ENSG00000141959      +  44300051
# ENSG00000142149  ENSG00000142149      +  31873315
# ENSG00000142156  ENSG00000142156      +  45981737
# ENSG00000142166  ENSG00000142166      +  33324477
# ENSG00000142168  ENSG00000142168      +  31659622
# ENSG00000142173  ENSG00000142173      +  46098097
# ENSG00000142178  ENSG00000142178      -  43427128
# ENSG00000142185  ENSG00000142185      +  44350163
# ENSG00000142188  ENSG00000142188      -  33480011

# %% [markdown]
# #### Initialize training and validation PersonalGenomeDatasets. For more information on how to adjust the parameters to PersonalGenomeDataset to suit your needs, see https://github.com/mostafavilabuw/SAGEnet/blob/main/example_usage.ipynb and the class documentation.

# %%
train_dataset = SAGEnet.data.PersonalGenomeDataset(metadata=train_gene_meta, vcf_file_path=vcf_file_path, hg38_file_path=hg19_path, sample_list=train_samps, y_data=expr_df,contig_prefix='',verbose=False)
val_subs_dataset = SAGEnet.data.PersonalGenomeDataset(metadata=train_gene_meta, vcf_file_path=vcf_file_path, hg38_file_path=hg19_path, sample_list=train_samps, y_data=expr_df,contig_prefix='',verbose=False)
val_genes_dataset = SAGEnet.data.PersonalGenomeDataset(metadata=val_gene_meta, vcf_file_path=vcf_file_path, hg38_file_path=hg19_path, sample_list=val_samps, y_data=expr_df,contig_prefix='',verbose=False)

train_dataloader = DataLoader(train_dataset,shuffle=True,num_workers=1)
val_subs_dataloader = DataLoader(val_subs_dataset, shuffle=False,num_workers=1)
val_genes_dataloader = DataLoader(val_genes_dataset,shuffle=False,num_workers=1)
# Out:
# acceptable maf range: -1<maf<2
# avg is mean
# acceptable maf range: -1<maf<2
# avg is mean
# acceptable maf range: -1<maf<2
# avg is mean

# %% [markdown]
# #### Initialize a p-SAGE-net model. For more information on how to adjust the parameters to PersonalGenomeDataset to suit your needs, see https://github.com/mostafavilabuw/SAGEnet/blob/main/example_usage.ipynb and the class documentation.

# %%
my_model = pSAGEnet(model_save_dir=model_save_dir)

# %% [markdown]
# #### Set up for model training:

# %%
val_dataloaders=[val_subs_dataloader,val_genes_dataloader]
es = EarlyStopping(monitor="train_gene_val_sub_diff_loss/dataloader_idx_0", patience=5,mode='min')
lr_monitor = LearningRateMonitor(logging_interval='epoch')

# used to save every model epoch 
all_epoch_checkpoint_callback = ModelCheckpoint(
    dirpath=model_save_dir,  
    filename="{epoch}",  
    save_top_k=-1,  
    every_n_epochs=1,
    save_last=False
)

# save last ckpt to be able to resume model training if job is killed 
last_checkpoint_callback = ModelCheckpoint(
    dirpath=model_save_dir,
    filename="last",     
    save_top_k=0,        
    every_n_train_steps=300,  
    save_last=True      
)

ckpt_list = [all_epoch_checkpoint_callback,last_checkpoint_callback]

# %% [markdown]
# #### Set up a trainer:

# %%
wandb_logger = WandbLogger(project='test_project_name', name='test_job_name', id='test_job_name', resume="allow") # change these based on your logging preferences 
device=2 # indicates which GPU
num_nodes=1 # single node training 
max_epochs=1 

trainer = pl.Trainer(
    accelerator="gpu", 
    devices=[int(device)] if device else 1, 
    num_nodes=num_nodes, 
    strategy="ddp" if not device else 'auto', 
    callbacks=ckpt_list, 
    max_epochs=max_epochs, 
    benchmark=False, 
    profiler='simple', 
    gradient_clip_val=1, 
    logger=wandb_logger, 
    log_every_n_steps=10)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# #### Train!

# %%
trainer.fit(my_model, train_dataloader, val_dataloaders=val_dataloaders)
# Out:
# You are using a CUDA device ('NVIDIA RTX A4000') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /homes/gws/aspiro17/.netrc
# wandb: Currently logged in as: spiroannae (spiroannae-university-of-washington) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/run-20250731_194909-test_job_name</code>
# Resuming run <strong><a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name/runs/test_job_name' target="_blank">test_job_name</a></strong> to <a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name' target="_blank">https://wandb.ai/spiroannae-university-of-washington/test_project_name</a>
#  View run at <a href='https://wandb.ai/spiroannae-university-of-washington/test_project_name/runs/test_job_name' target="_blank">https://wandb.ai/spiroannae-university-of-washington/test_project_name/runs/test_job_name</a>
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:658: Checkpoint directory /homes/gws/aspiro17/SAGEnet/example_notebooks/data/mostafavilab/personal_genome_expr/revisions/GEUVADIS/res exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name               | Type       | Params | Mode
# ----------------------------------------------------------
# 0 | conv0              | Sequential | 36.9 K | train
# 1 | convlayers         | ModuleList | 2.5 M  | train
# 2 | dilated_convlayers | ModuleList | 0      | train
# 3 | fc0                | Sequential | 65.8 K | train
# 4 | fclayers           | ModuleList | 65.8 K | train
# 5 | diff_fclayers      | ModuleList | 65.8 K | train
# 6 | diff_out           | Sequential | 257    | train
# 7 | ref_out            | Sequential | 257    | train
# ----------------------------------------------------------
# 2.7 M     Trainable params
# 0         Non-trainable params
# 2.7 M     Total params
# 10.811    Total estimated model params size (MB)
# 50        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1036.)
#   return F.conv1d(
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /homes/gws/aspiro17/miniconda3/envs/SAGEnet/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# Validation: |          | 0/? [00:00<?, ?it/s]
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:41859552 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44280061 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31853530 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:45961848 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33304490 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:31639128 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:46078115 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:43407150 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:44330334 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:33460081 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:26151131 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:36136941 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:36136941 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:36136941 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:36136941 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:36136941 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'BD' at 21:36136941 is not defined in the header, assuming Type=String
# [W::vcf_parse_format] FORMAT 'PP' at 21:36136941 is not defined in the header, assuming Type=String
# ...
# |  [Callback]ModelSummary.on_train_start                                                                                                                            	|  3.0998e-05     	|  1              	|  3.0998e-05     	|  3.8261e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                 	|  1.3e-05        	|  2              	|  2.5999e-05     	|  3.2091e-05     	|
# |  [LightningModule]pSAGEnet.on_validation_end                                                                                                                      	|  1.2063e-05     	|  2              	|  2.4126e-05     	|  2.9778e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_end        	|  1.2043e-05     	|  2              	|  2.4086e-05     	|  2.9729e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                    	|  2.1952e-05     	|  1              	|  2.1952e-05     	|  2.7095e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                       	|  1.0489e-05     	|  2              	|  2.0979e-05     	|  2.5894e-05     	|
# |  [LightningModule]pSAGEnet.on_train_start                                                                                                                         	|  1.9918e-05     	|  1              	|  1.9918e-05     	|  2.4585e-05     	|
# |  [LightningModule]pSAGEnet.on_validation_start                                                                                                                    	|  7.164e-06      	|  2              	|  1.4328e-05     	|  1.7685e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                               	|  6.1372e-06     	|  2              	|  1.2274e-05     	|  1.515e-05      	|
# |  [LightningModule]pSAGEnet.on_train_epoch_start                                                                                                                   	|  1.07e-05       	|  1              	|  1.07e-05       	|  1.3207e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                     	|  5.2948e-06     	|  2              	|  1.059e-05      	|  1.3071e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                         	|  4.7334e-06     	|  2              	|  9.4669e-06     	|  1.1685e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                    	|  8.0853e-06     	|  1              	|  8.0853e-06     	|  9.9796e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                      	|  7.0529e-06     	|  1              	|  7.0529e-06     	|  8.7054e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                	|  3.1916e-06     	|  2              	|  6.3833e-06     	|  7.8788e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                  	|  6.3321e-06     	|  1              	|  6.3321e-06     	|  7.8156e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                     	|  5.2699e-06     	|  1              	|  5.2699e-06     	|  6.5046e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                             	|  5.1097e-06     	|  1              	|  5.1097e-06     	|  6.3069e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start             	|  3.797e-06      	|  1              	|  3.797e-06      	|  4.6866e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                              	|  3.607e-06      	|  1              	|  3.607e-06      	|  4.4521e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                        	|  1.7984e-06     	|  2              	|  3.5968e-06     	|  4.4395e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                              	|  1.6983e-06     	|  2              	|  3.3965e-06     	|  4.1923e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                   	|  1.6287e-06     	|  2              	|  3.2573e-06     	|  4.0205e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint         	|  1.6028e-06     	|  2              	|  3.2056e-06     	|  3.9567e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end    	|  1.5977e-06     	|  2              	|  3.1954e-06     	|  3.944e-06      	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                        	|  3.1856e-06     	|  1              	|  3.1856e-06     	|  3.932e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start        	|  1.5625e-06     	|  2              	|  3.1251e-06     	|  3.8572e-06     	|
# |  [LightningModule]pSAGEnet.configure_callbacks                                                                                                                    	|  2.9663e-06     	|  1              	|  2.9663e-06     	|  3.6612e-06     	|
# |  [LightningModule]pSAGEnet.on_save_checkpoint                                                                                                                     	|  1.4477e-06     	|  2              	|  2.8955e-06     	|  3.5739e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_epoch_end  	|  1.4382e-06     	|  2              	|  2.8764e-06     	|  3.5503e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_save_checkpoint       	|  1.4077e-06     	|  2              	|  2.8154e-06     	|  3.475e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start               	|  2.725e-06      	|  1              	|  2.725e-06      	|  3.3635e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                 	|  1.3474e-06     	|  2              	|  2.6948e-06     	|  3.3262e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_start      	|  1.3069e-06     	|  2              	|  2.6138e-06     	|  3.2261e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                               	|  2.5849e-06     	|  1              	|  2.5849e-06     	|  3.1905e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start  	|  1.2375e-06     	|  2              	|  2.475e-06      	|  3.0549e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                           	|  2.4652e-06     	|  1              	|  2.4652e-06     	|  3.0428e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_validation_epoch_start	|  1.1676e-06     	|  2              	|  2.3353e-06     	|  2.8824e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                       	|  2.2347e-06     	|  1              	|  2.2347e-06     	|  2.7583e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_start           	|  2.0941e-06     	|  1              	|  2.0941e-06     	|  2.5847e-06     	|
# |  [LightningModule]pSAGEnet.on_train_end                                                                                                                           	|  2.0941e-06     	|  1              	|  2.0941e-06     	|  2.5847e-06     	|
# |  [LightningModule]pSAGEnet.teardown                                                                                                                               	|  2.0037e-06     	|  1              	|  2.0037e-06     	|  2.4732e-06     	|
# |  [LightningModule]pSAGEnet.on_train_epoch_end                                                                                                                     	|  1.9739e-06     	|  1              	|  1.9739e-06     	|  2.4364e-06     	|
# |  [LightningModule]pSAGEnet.on_validation_epoch_start                                                                                                              	|  9.6159e-07     	|  2              	|  1.9232e-06     	|  2.3738e-06     	|
# |  [LightningModule]pSAGEnet.setup                                                                                                                                  	|  1.9227e-06     	|  1              	|  1.9227e-06     	|  2.3732e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                	|  1.8841e-06     	|  1              	|  1.8841e-06     	|  2.3255e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end        	|  1.8338e-06     	|  1              	|  1.8338e-06     	|  2.2634e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                  	|  1.8231e-06     	|  1              	|  1.8231e-06     	|  2.2502e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                      	|  1.804e-06      	|  1              	|  1.804e-06      	|  2.2266e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                   	|  1.7639e-06     	|  1              	|  1.7639e-06     	|  2.1772e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end               	|  1.763e-06      	|  1              	|  1.763e-06      	|  2.1761e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                     	|  1.743e-06      	|  1              	|  1.743e-06      	|  2.1513e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start       	|  1.7039e-06     	|  1              	|  1.7039e-06     	|  2.1031e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.teardown                 	|  1.6028e-06     	|  1              	|  1.6028e-06     	|  1.9783e-06     	|
# |  [LightningModule]pSAGEnet.on_fit_end                                                                                                                             	|  1.573e-06      	|  1              	|  1.573e-06      	|  1.9415e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_end             	|  1.533e-06      	|  1              	|  1.533e-06      	|  1.8921e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end                 	|  1.533e-06      	|  1              	|  1.533e-06      	|  1.8921e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_sanity_check_end      	|  1.5032e-06     	|  1              	|  1.5032e-06     	|  1.8553e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_train_epoch_start     	|  1.5032e-06     	|  1              	|  1.5032e-06     	|  1.8553e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_fit_end               	|  1.4217e-06     	|  1              	|  1.4217e-06     	|  1.7548e-06     	|
# |  [LightningModule]pSAGEnet.on_fit_start                                                                                                                           	|  1.3327e-06     	|  1              	|  1.3327e-06     	|  1.645e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_fit_start             	|  1.2922e-06     	|  1              	|  1.2922e-06     	|  1.595e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start      	|  1.2722e-06     	|  1              	|  1.2722e-06     	|  1.5703e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 300, 'every_n_epochs': 0, 'train_time_interval': None}.on_sanity_check_start    	|  1.1623e-06     	|  1              	|  1.1623e-06     	|  1.4346e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
